# %%
from bs4 import BeautifulSoup
import requests
import time
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
uiuc_faculty_url = 'https://math.illinois.edu/directory/faculty'
html_text = requests.get(uiuc_faculty_url).text

# %%
def personal_website_text(url):
    spw = BeautifulSoup(requests.get(url).text, 'lxml') 
    return spw.text.lower()

# %%
# print(html_text)

# %%
soup = BeautifulSoup(html_text, 'lxml')

# %%
cards = soup.find_all('article', class_='profile-card')

# lists for DataFrame
names = []
titles = []
websites = []
does_research = []
mentions_diff_eq = []

sentinel = 0
h = time.time()

print('Starting!!!')

for card in cards:
    
    # get the card data, split to nicely have all components separated
    card_data = card.text.split('\n')
    # clean the card data
    prof_data = [d for d in card_data if d!='']
    
    # append the name
    names.append(prof_data[0])
    # append the title
    titles.append(prof_data[1])
    # append the website
    pw_url = 'https://math.illinois.edu' + card.find('a', class_='profile-card__link')['href']
    websites.append(pw_url)
    
    # get the more personal website's text
    pw_text = personal_website_text(pw_url)
    
    # append if the word 'research' appears in the personal website
    does_research.append('research' in pw_text)
    # append if the word 'differential equation' appears in the personal website
    mentions_diff_eq.append('differential equation' in pw_text)
    
    # increase sentinel
    sentinel+=1
    
    # print progess every ten faculty
    if sentinel % 10 == 0.0:
        print("{t:.2f}s: Done with {s} people...".format(t=time.time() - h, s=sentinel))
    
    # sleep time for requests
    time.sleep(1)
    
print('Done!!!')
# Out:
# Starting!!!
# 13.42s: Done with 10 people...
# 27.83s: Done with 20 people...
# 43.39s: Done with 30 people...
# 59.66s: Done with 40 people...
# 75.97s: Done with 50 people...
# 92.62s: Done with 60 people...
# 109.43s: Done with 70 people...
# 125.90s: Done with 80 people...
# 141.75s: Done with 90 people...
# 157.68s: Done with 100 people...
# 173.51s: Done with 110 people...
# 190.16s: Done with 120 people...
# 209.92s: Done with 130 people...
# 251.59s: Done with 140 people...
# 271.15s: Done with 150 people...
# 289.28s: Done with 160 people...
# 307.70s: Done with 170 people...
# Done!!!

# %%
# make a DataFrame to store all the data
d = {'name': names, 
     'title': titles,
     'website': websites,
     'does_research': does_research,
     'mentions_diff_eq': mentions_diff_eq}

df = pd.DataFrame(data=d)
df
# Out:
#                   name                                              title  \
# 0       Scott  Ahlgren                                          Professor
# 1         Pierre Albin           Professor and Helen Corley Petit Scholar
# 2         Matthew Ando  Professor of Mathematics and Associate Dean fo...
# 3         Jozsef Balog   Professor and J. Andrew and Susan Langan Scholar
# 4    Yuliy Baryshnikov  Professor of Mathematics and Electrical and Co...
# ..                 ...                                                ...
# 173  Paul M.  Weichsel                                 Professor Emeritus
# 174    Elliot Weinberg                                 Professor Emeritus
# 175    Douglas B. West                                 Professor Emeritus
# 176    John E.  Wetzel                                 Professor Emeritus
# 177        Jang-Mei Wu                                 Professor Emeritus
#
#                                                website  does_research  \
# 0    https://math.illinois.edu/directory/profile/sa...           True
# 1    https://math.illinois.edu/directory/profile/pa...           True
# 2    https://math.illinois.edu/directory/profile/mando           True
# 3    https://math.illinois.edu/directory/profile/jobal           True
# 4      https://math.illinois.edu/directory/profile/ymb           True
# ..                                                 ...            ...
# 173  https://math.illinois.edu/directory/profile/we...           True
# 174    https://math.illinois.edu/directory/profile/ecw           True
# 175  https://math.illinois.edu/directory/profile/dwest           True
# 176  https://math.illinois.edu/directory/profile/j-...           True
# 177   https://math.illinois.edu/directory/profile/jmwu           True
#
#      mentions_diff_eq
# 0               False
# 1               False
# 2               False
# 3               False
# 4               False
# ..                ...
# 173             False
# 174             False
# 175             False
# 176             False
# 177              True
#
# [178 rows x 5 columns]

# %%
df['does_research'].value_counts()
# Out:
# True    178
# Name: does_research, dtype: int64

# %%
df['mentions_diff_eq'].value_counts()

# %%
df[df['mentions_diff_eq']]
# Out:
#                     name                                              title  \
# 9          Alfred  Chong                                Assistant Professor
# 10           Lee DeVille            Director of Graduate Studies, Professor
# 17    M. Burak  Erdoğan                                           Professor
# 26     Vera Mikyoung Hur  Professor and Philippe Tondeur ScholarBrad and...
# 32      Kay  Kirkpatrick  Associate Professor, Blackwell Scholar, and He...
# 33   Eduard-Wilhelm Kirr                                Associate Professor
# 37   Richard S. Laugesen                                          Professor
# 49             Zoi Rapti                                Associate Professor
# 52          Renming Song                                          Professor
# 59     Nikolaos Tzirakis                                          Professor
# 63      Vadim Zharnitsky                                          Professor
# 107            Zhao Yang             J.L. Doob Research Assistant Professor
# 128   Ararat Babakhanian                                 Professor Emeritus
# 170     Philippe Tondeur                                 Professor Emeritus
# 177          Jang-Mei Wu                                 Professor Emeritus
#
#                                                website  does_research  \
# 9    https://math.illinois.edu/directory/profile/wf...           True
# 10   https://math.illinois.edu/directory/profile/rd...           True
# 17   https://math.illinois.edu/directory/profile/be...           True
# 26   https://math.illinois.edu/directory/profile/ve...           True
# 32   https://math.illinois.edu/directory/profile/kk...           True
# 33   https://math.illinois.edu/directory/profile/ekirr           True
# 37   https://math.illinois.edu/directory/profile/la...           True
# 49   https://math.illinois.edu/directory/profile/zr...           True
# 52   https://math.illinois.edu/directory/profile/rsong           True
# 59   https://math.illinois.edu/directory/profile/tz...           True
# 63     https://math.illinois.edu/directory/profile/vzh           True
# 107  https://math.illinois.edu/directory/profile/zh...           True
# 128  https://math.illinois.edu/directory/profile/ab...           True
# 170  https://math.illinois.edu/directory/profile/to...           True
# 177   https://math.illinois.edu/directory/profile/jmwu           True
#
#      mentions_diff_eq
# 9                True
# 10               True
# 17               True
# 26               True
# 32               True
# 33               True
# 37               True
# 49               True
# 52               True
# 59               True
# 63               True
# 107              True
# 128              True
# 170              True
# 177              True

# %%
df.to_csv('uiuc_all.csv')
df[df['mentions_diff_eq']].to_csv('uiuc_diff_eq.csv')
